# %%
from climatology_model import ClimatologyProbabilisticModel
from climatology_metrics import ClimatologyModelEvaluation
from estimate_gaussian_parameters import GaussianEstimation
from time_conversion import TimeFormatConverter
import xarray as xr
import argparse


def main():
    # Example script to run
    obs_path = 'gs://weatherbench2/datasets/era5/1959-2022-6h-64x32_equiangular_with_poles_conservative.zarr'
    obs_data = xr.open_zarr(obs_path)
    print("main debug 1")
    means_model = ClimatologyProbabilisticModel(obs_data, 2010, 2019, weather_variable='geopotential')
    print("main debug 2")
    means_model.create_climatology_model()
    print("main debug 3")
    probability_model = GaussianEstimation(means_model.forecast_probabilities)
    print("main debug 4")
    probability_model.estimate_gaussian_confidence_intervals()
    print("main debug 5")
    return probability_model.model_with_CI
    finalized_model = TimeFormatConverter(probability_model.model_with_CI)
    print("main debug 6")
    finalized_model.convert_time_format_for_intervals(variable="geopotential")
    print("main debug 7")
    finalized_model.save_as_zarr(finalized_model.predictions_model, "2010-2019", "geopotential")
    print("finished")
    metric_evaluation = ClimatologyModelEvaluation(finalized_model.predictions_model)
    return metric_evaluation.calculate_proportion_of_ones()

if __name__ == "__main__":
    result = main()

# %%
result.geopotential
# Out:
# <xarray.DataArray 'geopotential' (time: 366, level: 13, longitude: 64,
#                                   latitude: 32)>
# dask.array<sub, shape=(366, 13, 64, 32), dtype=float32, chunksize=(366, 13, 64, 32), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) int64 1 2 3 4 5 6 7 8 ... 359 360 361 362 363 364 365 366
#   * level      (level) int64 50 100 150 200 250 300 400 500 600 700 850 925 1000
#   * longitude  (longitude) float64 0.0 5.625 11.25 16.88 ... 343.1 348.8 354.4
#   * latitude   (latitude) float64 -90.0 -84.19 -78.39 ... 78.39 84.19 90.0

# %%
finalized_model = TimeFormatConverter(result)
print("main debug 6")
finalized_model.convert_time_format_for_intervals(variable="geopotential")
print("main debug 7")
finalized_model.save_as_zarr(finalized_model.predictions_model, "2010-2019", "geopotential")
print("finished")
metric_evaluation = ClimatologyModelEvaluation(finalized_model.predictions_model)
#metric_evaluation.calculate_proportion_of_ones()
# Out:
# main debug 6
# debug start
# debug: 1
# debug: 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/weather-research/lib/python3.11/site-packages/xarray/core/dataset.py:1393, in Dataset._construct_dataarray(self, name)
#    1392 try:
# -> 1393     variable = self._variables[name]
#    1394 except KeyError:
#
# KeyError: 'geopotential_upper'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/davidhuang/Desktop/Weather-Research /Probabilistic-Weather-Forecasting-/testing.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/davidhuang/Desktop/Weather-Research%20/Probabilistic-Weather-Forecasting-/testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> finalized_model = TimeFormatConverter(result)
#       <a href='vscode-notebook-cell:/Users/davidhuang/Desktop/Weather-Research%20/Probabilistic-Weather-Forecasting-/testing.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> print("main debug 6")
# ----> <a href='vscode-notebook-cell:/Users/davidhuang/Desktop/Weather-Research%20/Probabilistic-Weather-Forecasting-/testing.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> finalized_model.convert_time_format_for_intervals(variable="geopotential")
#       <a href='vscode-notebook-cell:/Users/davidhuang/Desktop/Weather-Research%20/Probabilistic-Weather-Forecasting-/testing.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> print("main debug 7")
#       <a href='vscode-notebook-cell:/Users/davidhuang/Desktop/Weather-Research%20/Probabilistic-Weather-Forecasting-/testing.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> finalized_model.save_as_zarr(finalized_model.predictions_model, "2010-2019", "geopotential")
#
# File ~/Desktop/Weather-Research /Probabilistic-Weather-Forecasting-/time_conversion.py:32, in TimeFormatConverter.convert_time_format_for_intervals(self, lead_time, variable)
#      30 for date in datetime_values:
#      31     day_of_year = date.dayofyear
# ---> 32     new_dataset["geopotential_upper"].loc[date] = self.predictions_model["geopotential_upper"].sel(time=day_of_year, method="nearest")
#      33     new_dataset["geopotential_lower"].loc[date] = self.predictions_model["geopotential_lower"].sel(time=day_of_year, method="nearest")
#      35 print("debug: 3")
#
# File ~/anaconda3/envs/weather-research/lib/python3.11/site-packages/xarray/core/dataset.py:1484, in Dataset.__getitem__(self, key)
#    1482     return self.isel(**key)
#    1483 if utils.hashable(key):
# -> 1484     return self._construct_dataarray(key)
#    1485 if utils.iterable_of_hashable(key):
#    1486     return self._copy_listed(key)
#
# File ~/anaconda3/envs/weather-research/lib/python3.11/site-packages/xarray/core/dataset.py:1395, in Dataset._construct_dataarray(self, name)
#    1393     variable = self._variables[name]
#    1394 except KeyError:
# -> 1395     _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1397 needed_dims = set(variable.dims)
#    1399 coords: dict[Hashable, Variable] = {}
#
# File ~/anaconda3/envs/weather-research/lib/python3.11/site-packages/xarray/core/dataset.py:196, in _get_virtual_variable(variables, key, dim_sizes)
#     194 split_key = key.split(".", 1)
#     195 if len(split_key) != 2:
# --> 196     raise KeyError(key)
#     198 ref_name, var_name = split_key
#     199 ref_var = variables[ref_name]
#
# KeyError: 'geopotential_upper'
